# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt

# load the dataset
ds = pd.read_csv('train.csv', index_col=0)
pd.set_option('display.max_columns', 80)
# Out:
#                                                        Sex  Age  \
# Path
# CheXpert-v1.0-small/train/patient00001/study1/v...  Female   68
# CheXpert-v1.0-small/train/patient00002/study2/v...  Female   87
# CheXpert-v1.0-small/train/patient00002/study1/v...  Female   83
# CheXpert-v1.0-small/train/patient00002/study1/v...  Female   83
# CheXpert-v1.0-small/train/patient00003/study1/v...    Male   41
#
#                                                    Frontal/Lateral AP/PA  \
# Path
# CheXpert-v1.0-small/train/patient00001/study1/v...         Frontal    AP
# CheXpert-v1.0-small/train/patient00002/study2/v...         Frontal    AP
# CheXpert-v1.0-small/train/patient00002/study1/v...         Frontal    AP
# CheXpert-v1.0-small/train/patient00002/study1/v...         Lateral   NaN
# CheXpert-v1.0-small/train/patient00003/study1/v...         Frontal    AP
#
#                                                     No Finding  \
# Path
# ...

# %%
# sex distribution
ds["Sex"].value_counts('Female')
ds.shape
# Out:
# (223414, 18)

# %%
# age distribution
age_range_0 = (0, 10)
age_range_1 = (11, 20)
age_range_2 = (21, 30)
age_range_3 = (31, 40)
age_range_4 = (41, 50)
age_range_5 = (51, 60)
age_range_6 = (61, 70)
age_range_7 = (71, 80)
age_range_8 = (81, 90)
age_range_9 = (91, 100)

count_within_range = ds[(ds['Age'] >= age_range_0[0]) & (ds['Age'] <= age_range_0[1])].shape[0]
print(f"Number of samples in the age range {age_range_0}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_1[0]) & (ds['Age'] <= age_range_1[1])].shape[0]
print(f"Number of samples in the age range {age_range_1}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_2[0]) & (ds['Age'] <= age_range_2[1])].shape[0]
print(f"Number of samples in the age range {age_range_2}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_3[0]) & (ds['Age'] <= age_range_3[1])].shape[0]
print(f"Number of samples in the age range {age_range_3}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_4[0]) & (ds['Age'] <= age_range_4[1])].shape[0]
print(f"Number of samples in the age range {age_range_4}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_5[0]) & (ds['Age'] <= age_range_5[1])].shape[0]
print(f"Number of samples in the age range {age_range_5}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_6[0]) & (ds['Age'] <= age_range_6[1])].shape[0]
print(f"Number of samples in the age range {age_range_6}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_7[0]) & (ds['Age'] <= age_range_7[1])].shape[0]
print(f"Number of samples in the age range {age_range_7}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_8[0]) & (ds['Age'] <= age_range_8[1])].shape[0]
print(f"Number of samples in the age range {age_range_8}: {count_within_range}")
count_within_range = ds[(ds['Age'] >= age_range_9[0]) & (ds['Age'] <= age_range_9[1])].shape[0]
print(f"Number of samples in the age range {age_range_9}: {count_within_range}")
# Out:
# Number of samples in the age range (0, 10): 3
# Number of samples in the age range (11, 20): 3220
# Number of samples in the age range (21, 30): 13758
# Number of samples in the age range (31, 40): 16465
# Number of samples in the age range (41, 50): 27358
# Number of samples in the age range (51, 60): 44693
# Number of samples in the age range (61, 70): 47979
# Number of samples in the age range (71, 80): 37712
# Number of samples in the age range (81, 90): 32226
# Number of samples in the age range (91, 100): 0

# %%
# continuous values
ds.describe()
# Out:
#                  Age  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# count  223414.000000     22381.0                44839.000000  46203.000000
# mean       60.430653         1.0                   -0.035795      0.409346
# std        17.820925         0.0                    0.718442      0.769323
# min         0.000000         1.0                   -1.000000     -1.000000
# 25%        49.000000         1.0                   -1.000000      0.000000
# 50%        62.000000         1.0                    0.000000      1.000000
# 75%        74.000000         1.0                    0.000000      1.000000
# max        90.000000         1.0                    1.000000      1.000000
#
#         Lung Opacity   Lung Lesion         Edema  Consolidation     Pneumonia  \
# count  117778.000000  11944.000000  85956.000000   70622.000000  27608.000000
# mean        0.848911      0.644508      0.456769      -0.183498     -0.461134
# ...

# %%
# categorical values
ds.describe(include=['O'])
# Out:
#            Sex Frontal/Lateral   AP/PA
# count   223414          223414  191027
# unique       3               2       4
# top       Male         Frontal      AP
# freq    132636          191027  161590

# %%
# figure out what columns of features have missing values
ds.isnull().sum()[ds.isnull().sum()>0].sort_values(ascending = False)
# Out:
# AP/PA    32387
# dtype: int64

# %%
# drop the features to be ignored
ds = ds.drop(['AP/PA', 'Enlarged Cardiomediastinum','Lung Opacity','Lung Lesion','Edema', 'Consolidation', 'Atelectasis', 'Pneumothorax', 'Pleural Other', 'Fracture', 'Support Devices', 'No Finding'], axis = 1)

# %%
ds.head()
# Out:
#                                                        Sex  Age  \
# Path
# CheXpert-v1.0/train/patient00001/study1/view1_f...  Female   68
# CheXpert-v1.0/train/patient00002/study2/view1_f...  Female   87
# CheXpert-v1.0/train/patient00002/study1/view1_f...  Female   83
# CheXpert-v1.0/train/patient00002/study1/view2_l...  Female   83
# CheXpert-v1.0/train/patient00003/study1/view1_f...    Male   41
#
#                                                    Frontal/Lateral  \
# Path
# CheXpert-v1.0/train/patient00001/study1/view1_f...         Frontal
# CheXpert-v1.0/train/patient00002/study2/view1_f...         Frontal
# CheXpert-v1.0/train/patient00002/study1/view1_f...         Frontal
# CheXpert-v1.0/train/patient00002/study1/view2_l...         Lateral
# CheXpert-v1.0/train/patient00003/study1/view1_f...         Frontal
#
#                                                     Cardiomegaly  Pneumonia  \
# Path
# CheXpert-v1.0/train/patient00001/study1/view1_f...           0.0        0.0
# ...
